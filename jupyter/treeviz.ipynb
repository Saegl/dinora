# %%
import dinora.net
from dinora.mcts import MCTSparams

dnn_model = dinora.net.ChessModel(softmax_temp=1.6)

# %%
from dinora.metrics.treeviz import render_state, RenderParams

render_state(
    model=dnn_model,
    fen="7k/p6p/5q2/3pN3/3P2Q1/8/P1r4P/6K1 w - - 0 34",
    nodes=20,
    mcts_params=MCTSparams(c=8.0),
    # format='png',
    render_params=RenderParams(max_number_of_nodes=10),
)
# Out:
# info string e5g6 0 	(P: 6.12%) 	(Q: -1.0)
# info string e5c6 0 	(P: 6.11%) 	(Q: -1.0)
# info string e5c4 0 	(P: 6.11%) 	(Q: -1.0)
# info string g4g8 0 	(P: 6.11%) 	(Q: -1.0)
# info string g4c8 0 	(P: 6.12%) 	(Q: -1.0)
# info string g4g7 0 	(P: 6.11%) 	(Q: -1.0)
# info string g4d7 0 	(P: 6.13%) 	(Q: -1.0)
# info string g4g6 0 	(P: 6.11%) 	(Q: -1.0)
# info string g4e6 0 	(P: 6.11%) 	(Q: -1.0)
# info string g4g5 0 	(P: 6.13%) 	(Q: -1.0)
# info string g4f5 0 	(P: 6.13%) 	(Q: -1.0)
# info string g4h4 0 	(P: 6.13%) 	(Q: -1.0)
# info string g4f4 0 	(P: 6.11%) 	(Q: -1.0)
# info string g4e4 0 	(P: 6.11%) 	(Q: -1.0)
# info string g4g2 0 	(P: 6.11%) 	(Q: -1.0)
# info string g4e2 0 	(P: 6.15%) 	(Q: -1.0)
# info string e5f7 1 	(P: 6.16%) 	(Q: -0.25486)
# info string e5f3 1 	(P: 6.18%) 	(Q: -0.25486)
# info string e5d3 1 	(P: 6.18%) 	(Q: -0.25486)
# info string g4h3 1 	(P: 6.2%) 	(Q: -0.25486)
# info string g4g3 1 	(P: 6.24%) 	(Q: -0.25486)
# info string g4f3 1 	(P: 6.2%) 	(Q: -0.25486)
# ...

# %%
from dinora.metrics.treeviz import render_search_process

render_search_process(
    model=dnn_model,
    fen="r1bqkb1r/pppp1ppp/2n5/1B2p3/4n3/5N2/PPPP1PPP/RNBQ1RK1 w kq - 0 5",
    nodes=20,
    mcts_params=MCTSparams(c=2.0)
)
# Out:
# info string b5c6 0 	(P: 6.36%) 	(Q: -1.0)
# info string b5a6 0 	(P: 6.28%) 	(Q: -1.0)
# info string b5c4 0 	(P: 6.28%) 	(Q: -1.0)
# info string b5a4 0 	(P: 6.28%) 	(Q: -1.0)
# info string b5d3 0 	(P: 6.28%) 	(Q: -1.0)
# info string b5e2 0 	(P: 6.28%) 	(Q: -1.0)
# info string f3g5 0 	(P: 6.28%) 	(Q: -1.0)
# info string f3e5 0 	(P: 6.28%) 	(Q: -1.0)
# info string f3h4 0 	(P: 6.28%) 	(Q: -1.0)
# info string f3d4 0 	(P: 6.28%) 	(Q: -1.0)
# info string f3e1 0 	(P: 6.28%) 	(Q: -1.0)
# info string g1h1 0 	(P: 6.28%) 	(Q: -1.0)
# info string f1e1 0 	(P: 8.91%) 	(Q: -1.0)
# info string d1e2 0 	(P: 6.3%) 	(Q: -1.0)
# info string d1e1 0 	(P: 6.29%) 	(Q: -1.0)
# info string b1c3 0 	(P: 6.35%) 	(Q: -1.0)
# info string b1a3 0 	(P: 6.28%) 	(Q: -1.0)
# info string h2h3 0 	(P: 6.28%) 	(Q: -1.0)
# info string g2g3 0 	(P: 6.28%) 	(Q: -1.0)
# info string d2d3 0 	(P: 6.4%) 	(Q: -1.0)
# info string c2c3 0 	(P: 6.28%) 	(Q: -1.0)
# info string b2b3 0 	(P: 6.28%) 	(Q: -1.0)
# ...
